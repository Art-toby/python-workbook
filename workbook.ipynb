# %%
#CATENATION AND USE OF THE \ IN BETWEEN CHARACTERS TO AVOID AN ERROR: string manipulation
boo= "precious my sweetheart"
baby= 'this isn\'t working'
bae= "ROFL. \U0001F923"
length= len(boo)
print(boo,length, baby,bae)
# Out:
# precious my sweetheart 22 this isn't working ROFL. 🤣

# %%
# functions: to assighn a function you need to begin your statement with the 'def' statement 
def interest_rate(principal, rate, time):
    result= principal*(1 + rate)**time
    return result
interest_rate(1000, 20/100, 1)
# Out:
# 1200.0

# %%
#exercise 1
print(3*3)
print(144/12)
print(1565%3)
print((22/7+3.14**2)*3/0.025)
print(int(144**0.5))
pi=22/7
print(pi**0.5)
print(round((((3/(11**0.5))**2)*0.5*(7/9))**-1,2))
# Out:
# 9
# 12.0
# 2
# 1560.2948571428572
# 12
# 1.7728105208558367
# 3.14

# %%
#exercise 2
name= "Tobias"
print((name+" ")* 500)
# Out:
# Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias Tobias

# %%
#exercise 3
print(int(22/3))
# Out:
# 7

# %%
#exercise 4 and 5
print(name.lower())
print(name.upper())
len(name)
# Out:
# tobias
# TOBIAS
# 6

# %%
#exercise 6
x, y, z= 2**5, 130/5, 6*7
print(y==z)
print((y>x) and (z>y))
print(x>(y or z))
print((2*x>3*y-5) or (-y<z-2*x))
# Out:
# False
# False
# True
# True

# %%
#EXERCISE 7
variable3= 1

# %%
combine=(["Let's ", 'do ', 'this!'])
### START FUNCTION
def combine(words):
    # HINT: use the `.join()` string method to combine your words
    # type: `sentence = "".join(words)`
    sentence = "".join(words)
    return sentence
### END FUNCTION

# %%
word_list = ['be','have','do','say','get','make','go','know','take','see','come','think',
     'look','want','give','use','find','tell','ask','work','seem','feel','leave','call']
check = "S"
res = [idx for idx in word_list if idx.upper().startswith(check.upper())]
#res = [idx for idx in word_list if idx[0].lower() == check.lower()]
print(res)
# Out:
# ['say', 'see', 'seem']

# %%
my_list= [['ARON', '0.1'], ['BEY', '0.2'], ['ABI', '0.05'], ['ZBBY', '0.9'], ['KB', '0.4']]

result = []

for i in my_list: 
    if i[0][0] == 'a'.upper():
          result.append(i[0]) 

print(result)
# Out:
# ['ARON', 'ABI']

# %%
 == ['xanadu', 'xyz', 'aardvark', 'apple', 'mix']
### START FUNCTION
def front_x(list_of_words):
    # your code here
    # HINT: create two lists (one will contain words that start with X, the other not):
    list_x = []
    list_not_x = [word for word in list_of_words if word[0].lower() != "x"]
    # HINT: loop through words 
    for word in list_of_words:
        # HINT: use `if` to check if `word[0] == "x"`
        if word[0] == "x":
        # HINT: add the word to the list it belongs using e.g. `list_x.append(word)`
            list_x.append(word)
        
    # HINT: sort the lists outside of the for loop using e.g. `list_x.sort()`
    list_x.sort()
    # HINT: add the lists together and return `list_x + list_not_x`        
    
    return list_x + sorted(list_not_x)
### END FUNCTION
# Out:
#   File "C:\Users\PC\AppData\Local\Temp/ipykernel_10032/2395190748.py", line 1
#     == ['xanadu', 'xyz', 'aardvark', 'apple', 'mix']
#     ^
# SyntaxError: invalid syntax

# %%
numbers = [2,3,4,5]

list(map(lambda a: a**2, numbers)) # We are mapping the lambda function to iterate over the list `numbers`
# Out:
# [4, 9, 16, 25]

# %%
3%2
# Out:
# 1

# %%
nums = [1, 2, 3, 4, 5, 6]

[x**2 for x in nums if x%2==0]
# Out:
# [4, 16, 36]

# %%
nums = [1,1,1,2,2,3,3,3,5,5,1,1,1]
def remove_adjacent(nums):
   
    numstail = [i for i in range(0,len(nums))] 
    nums = nums + numstail

    for i in nums:
        if nums[i] == nums[i-1]:
            del nums[i]

    return nums[:-len(numstail)]

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-5,5,0.1)     # range of values for z
mu = 0                      # mu = 0 for standard normal
sigma = 3                    # mu = 1 for standard normal

# now calculate f(x)
f = 1 / np.sqrt ((2 * np.pi * sigma ** 2)) * np.exp (-0.5 * ((x - mu) / sigma) ** 2)

plt.rcParams["figure.figsize"] = (10,6)
plt.plot(x,f,'k')
plt.show()

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import pandas as pd

x = np.arange(1.2,2.2,0.01)    # Range of values for height from 1.2m to 2.2m
mu = 1.7                       # mu -> distribution mean = 1.7m
sigma = 0.1                    # sigma -> standard deviation = 0.1m

# We now calculate f(x), the probability density function of our normal distribution. 
f = st.norm.pdf(x, loc = mu, scale = sigma)

p = st.norm.cdf(1.5, loc = mu, scale = sigma)
print(f'The probability that a random data scientist has a height of 1.5 m is {np.round(p*100,2)} %') # F(1.5), i.e. probability of observing a height <= 1.5m

# Plot the results
plt.rcParams["figure.figsize"] = (10,6)
plt.plot(x,f,'r', label = 'Height normal distribution')
plt.axvline(x = 1.5, color = 'b', linestyle = '--', label = '1.5m Tall')
plt.legend()
plt.show()
# Out:
# The probability that a random data scientist has a height of 1.5 m is 2.28 %

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(url= "https://github.com/Explore-AI/Pictures/blob/master/PEP_8_Guide.jpg?raw=true")
# Out:
# <img src="https://github.com/Explore-AI/Pictures/blob/master/PEP_8_Guide.jpg?raw=true"/>

# %%
original= [1, 2, 2, 3]
newlist=[]

for item in original:
    if item in newlist:
        print ("You don't need to add "+str(item)+" again.")
    else:
        newlist.append(item)
        print ("Added "+str(item))

print (newlist)
# Out:
# Added 1
# Added 2
# You don't need to add 2 again.
# Added 3
# [1, 2, 3]

# %%
def remove_adjacent(nums):
    return[k for k, g in nums.groupby()]

# %%
remove_adjacent([27, -5, 13, 13, 0]) == [27, -5, 13, 0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4412/2268932379.py in <module>
# ----> 1 remove_adjacent([27, -5, 13, 13, 0]) == [27, -5, 13, 0]
#
# ~\AppData\Local\Temp/ipykernel_4412/2563220888.py in remove_adjacent(nums)
#       1 def remove_adjacent(nums):
# ----> 2     return[k for k, g in nums.groupby()]
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
# Out:
# X
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4412/1991345101.py in <module>
#      10     return complement(seq[::-1])
#      11
# ---> 12 print(reverse_complement("TCGGGCCCCX"))
#
# ~\AppData\Local\Temp/ipykernel_4412/1991345101.py in reverse_complement(seq)
#       8         return ''.join(letters)
#       9 def reverse_complement(seq):
# ---> 10     return complement(seq[::-1])
#      11
#      12 print(reverse_complement("TCGGGCCCCX"))
#
# ~\AppData\Local\Temp/ipykernel_4412/1991345101.py in complement(seq)
#       5         if element not in complement:
#       6             print (element)
# ----> 7         letters = [complement[base] for base in element]
#       8         return ''.join(letters)
#       9 def reverse_complement(seq):
#
# ~\AppData\Local\Temp/ipykernel_4412/1991345101.py in <listcomp>(.0)
#       5         if element not in complement:
#       6             print (element)
# ----> 7         letters = [complement[base] for base in element]
#       8         return ''.join(letters)
#       9 def reverse_complement(seq):
#
# KeyError: 'X'

# %%
str(9+1)
# Out:
# '10'

# %%
str(0+1)
# Out:
# '1'

# %%
1+2+3.0
# Out:
# 6.0

# %%
scores_1 = [2, 4, 3, 8]
scores_2 = [4, 4, 5, 3]
scores_1 + scores_2
# Out:
# [2, 4, 3, 8, 4, 4, 5, 3]

# %%
S=[2,3,4,5,7,8,32,2,13,4]
sorted(S)
# Out:
# [2, 2, 3, 4, 4, 5, 7, 8, 13, 32]

# %%
len(S)
# Out:
# 10

# %%
students = ["janneman", "jordan", "john", "jacob", "james"]

for i in range(students):
    if students[i][-1] != 'n' and students[i][-1] != 'b':
        print(students[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4412/2460935537.py in <module>
#       1 students = ["janneman", "jordan", "john", "jacob", "james"]
#       2
# ----> 3 for i in range(students):
#       4     if students[i][-1] != 'n' and students[i][-1] != 'b':
#       5         print(students[i])
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
a = [58, 45, 12]
a.extend([10])
print(a)
# Out:
# [58, 45, 12, 10]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# %matplotlib inline

mu = 0
variance = 2
sigma = np.log(variance) ,

x = np.linspace(mu-3*variance,mu+3*variance, 100)

plt.plot(x, norm.pdf(x^3) , mu, sigma)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4412/267881914.py in <module>
#      10 x = np.linspace(mu-3*variance,mu+3*variance, 100)
#      11
# ---> 12 plt.plot(x, norm.pdf(x^3) , mu, sigma)
#
# TypeError: ufunc 'bitwise_xor' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
# Contents of the module we are creating 
content = """
s = 'Hello ' 

def say_hi(name):
    print(s+name)

class Greet:
    pass
"""

# Write the above text to a file called my_module.py
# within our current working directory. 
with open('./my_module.py', 'w') as fp:
    fp.write(content)

# %%
#Import the module we've just made! 
import my_module
#(2)
my_module.s
#(3)
my_module.say_hi('Nelson')
# Out:
# Hello Nelson

# %%
import numpy as np
# Create an array by passing in a list of lists.
ratings = np.array([[94,89,63], [93,92,48], [92,94,56]])

ratings
# Out:
# array([[94, 89, 63],
#        [93, 92, 48],
#        [92, 94, 56]])

# %%
# Sum of each row.
ratings.sum(axis=0)
# Out:
# array([279, 275, 167])

# %%
#Import the module we've just made! 
import my_module
#(2)
my_module.s
#(3)
my_module.say_hi('Nelson')
# Out:
# Hello Nelson

# %%
# Sum of each row.
ratings.sum(axis=1)
# Out:
# array([246, 233, 242])

# %%
# Min of each row.
ratings.min(axis=1)
# Out:
# array([63, 48, 56])

# %%
# Min of each row.
ratings.min(axis=0)
# Out:
# array([92, 89, 48])

# %%
import pandas as pd #dataframe

# %%
#creating a list in dataframe using list of lists.note the double[[]], for numpy we create the dataframe by using np.array([[]]) 

# Create list of lists containing data.
list_df = [[32, 'Portugal', 94], [30, 'Argentina', 93], [25 , 'Brazil', 92]]

# Create index - names of players.
index = ['Christiano Ronaldo', 'Lionel Messi', 'Neymar']

# Create column names.
columns = ['Age', 'Nationality', 'Overall']

# Create dataframe by passing in data, index and columns.
pf=pd.DataFrame(data=list_df, index=index, columns=columns) #this makes the dataframe that we have created to be called pf

# %%
# we can use the iloc or loc function to get or slice certain data from our dataframe.
#iloc[] uses index numbers whereas loc[] uses names
#the difference between this and slicing by columns is 1: it can take for both row and columns and 2, it disoalys everything inbetween the selected columns
pf.loc['Age':'Overall']
# Out:
#                     Age Nationality  Overall
# Christiano Ronaldo   32    Portugal       94
# Lionel Messi         30   Argentina       93
# Neymar               25      Brazil       92

# %%
pf[['Age', 'Nationality']]
# Out:
#                     Age Nationality
# Christiano Ronaldo   32    Portugal
# Lionel Messi         30   Argentina
# Neymar               25      Brazil

# %%
# Load data - pass 'Name' as our index column.
# For this exercise, we'll use football player data to evaluate our dataframe.
load_df = pd.read_csv('https://raw.githubusercontent.com/Explore-AI/Public-Data/master/Data/fundamentals/football_players.csv', index_col='Name')

# Create dataframe called df.
df = pd.DataFrame(load_df)

# Use the head() function to look at the first 5 rows.
df.head()
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (14,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# L. Messi           95           95        96       77      ...        88
# Neymar             82           95        92       75      ...        81
# L. Suárez          60           91        83       77      ...        83
# M. Neuer           35           48        70       15      ...        55
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# L. Messi              85             26           87      73
# Neymar                80             33           90      78
# L. Suárez             87             38           77      89
# M. Neuer              25             11           61      44
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# L. Messi                   28       59      90      85                     RW
# Neymar                     24       53      80      83                     LW
# L. Suárez                  45       80      84      88                     ST
# M. Neuer                   10       83      70      11                     GK
#
# [5 rows x 38 columns]

# %%
df[['Age', 'Preferred Positions']] # this is a form of slicing the dataframe called by columns. it selects just the mentioned columns thereby ignoring the columns between the specified columns.
# Out:
#                    Age Preferred Positions
# Name
# Cristiano Ronaldo   32              ST LW
# L. Messi            30                 RW
# Neymar              25                 LW
# L. Suárez           30                 ST
# M. Neuer            31                 GK
# ...                ...                 ...
# A. Kelsey           17                 GK
# B. Richardson       47                 GK
# J. Young            17                 ST
# J. Lundstram        18                 CM
# L. Sackey           18              ST CB
#
# [17981 rows x 2 columns]

# %%
''''By index and column

We can also select a subset of the dataframe using indices and columns in combination. Let's look at a few examples:'''

df[['Age', 'Nationality']].iloc[0:5]  #this selects the interested columns and slices the data by the rows in the iloc index
# Out:
#                    Age Nationality
# Name
# Cristiano Ronaldo   32    Portugal
# L. Messi            30   Argentina
# Neymar              25      Brazil
# L. Suárez           30     Uruguay
# M. Neuer            31     Germany

# %%
df.iloc[0:5][['Age', 'Nationality']] #irrespective of the position the iloc when ccombined with the columns slicing assuming the row
# Out:
#                    Age Nationality
# Name
# Cristiano Ronaldo   32    Portugal
# L. Messi            30   Argentina
# Neymar              25      Brazil
# L. Suárez           30     Uruguay
# M. Neuer            31     Germany

# %%
#Select rows 9-14 of the football player dataframe we've just been using
df.iloc[9:15]
# Out:
#               Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# G. Higuaín     29   Argentina       90       78         50      75
# Sergio Ramos   31       Spain       90       75         84      79
# K. De Bruyne   26     Belgium       89       76         68      80
# T. Courtois    25     Belgium       89       46         23      61
# A. Sánchez     28       Chile       89       88         80      90
# L. Modrić      31     Croatia       89       75         62      93
#
#              Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                  ...
# G. Higuaín    69           85        86       68      ...        75
# Sergio Ramos  60           84        80       66      ...        78
# K. De Bruyne  75           87        84       90      ...        90
# T. Courtois   45           23        52       14      ...        32
# A. Sánchez    87           87        86       80      ...        81
# L. Modrić     94           92        84       78      ...        92
#
#              Shot power Sliding tackle Sprint speed Stamina Standing tackle  \
# Name
# G. Higuaín       88             18           80      72              22
# Sergio Ramos     79             91           77      84              89
# K. De Bruyne     85             40           75      87              51
# T. Courtois      36             16           52      38              18
# A. Sánchez       84             35           84      85              39
# L. Modrić        73             73           71      82              80
#
#              Strength  Vision Volleys Preferred Positions
# Name
# G. Higuaín     85      70      88                     ST
# Sergio Ramos   81      63      66                     CB
# K. De Bruyne   73      90      82              RM CM CAM
# T. Courtois    70      44      12                     GK
# A. Sánchez     72      83      83            RM LW ST LM
# L. Modrić      58      90      74                 CDM CM
#
# [6 rows x 38 columns]

# %%
#Select, in order, only the "Preferred Positions", "Overall" and "Age" columns for the football player Neymar
df[["Preferred Positions", "Overall", "Age"]].loc['Neymar']
# Out:
# Preferred Positions    LW
# Overall                 92
# Age                     25
# Name: Neymar, dtype: object

# %%
#Select, in order, only the "Overall", "Age" and "Nationality" columns for all players with ages of 35 years or older
df[["Overall", "Age", "Nationality" ]][df["Age"]>= 35]
# Out:
#                 Overall  Age     Nationality
# Name
# G. Buffon            89   39           Italy
# Z. Ibrahimović       88   35          Sweden
# P. Čech              86   35  Czech Republic
# A. Barzagli          85   36           Italy
# Aduriz               84   36           Spain
# ...                 ...  ...             ...
# R. Kawai             52   38           Japan
# Y. Nishibe           52   36           Japan
# A. Al Basisi         52   39    Saudi Arabia
# P. Jennings          52   37         England
# B. Richardson        46   47         England
#
# [468 rows x 3 columns]

# %%
# Sort by age from youngest to oldest (select first 5 entries).
df.sort_values('Age').head()
# Out:
#               Age  Nationality  Overall Acceleration Aggression Agility  \
# Name
# J. Romero      16    Argentina       58       75         36      70
# J. Hove        16       Norway       51       57         57      58
# Javi Vázquez   16        Spain       58       61         53      48
# K. Pierie      16  Netherlands       65       72         64      66
# L. Pintor      16       France       54       72         29      70
#
#              Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                  ...
# J. Romero     86           55        59       46      ...        52
# J. Hove       56           51        42       40      ...        56
# Javi Vázquez  65           47        43       33      ...        41
# K. Pierie     53           65        66       47      ...        68
# L. Pintor     68           56        43       27      ...        30
#
#              Shot power Sliding tackle Sprint speed Stamina Standing tackle  \
# Name
# J. Romero        54             25           77      58              26
# J. Hove          50             56           64      47              51
# Javi Vázquez     42             59           64      59              63
# K. Pierie        35             62           72      45              67
# L. Pintor        57             12           68      36              10
#
#              Strength  Vision Volleys Preferred Positions
# Name
# J. Romero      41      51      45                     ST
# J. Hove        54      56      29                     CM
# Javi Vázquez   55      37      29                     CB
# K. Pierie      65      56      32                  LB CB
# L. Pintor      34      38      48                     ST
#
# [5 rows x 38 columns]

# %%
# Sort by age from oldest to youngest (select first 5 entries).
df.sort_values('Age', ascending=False).head() #this sorts in descending order because the ascending statement is false
# Out:
#                Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# B. Richardson   47     England       46       25         44      35
# E. El Hadary    44       Egypt       70       28         29      21
# O. Pérez        44      Mexico       71       60         26      69
# J. Walker       43     England       55       22         41      53
# D. Coyne        43       Wales       55       36         36      48
#
#               Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                   ...
# B. Richardson  44           22        44       11      ...        12
# E. El Hadary   41           25        57       20      ...        16
# O. Pérez       69           23        50       19      ...        26
# J. Walker      64           38        35       16      ...        22
# D. Coyne       58           31        57       13      ...        28
#
#               Shot power Sliding tackle Sprint speed Stamina Standing tackle  \
# Name
# B. Richardson     13             13           25      32              12
# E. El Hadary      18             15           39      34              19
# O. Pérez          24             11           57      41              12
# J. Walker         22             13           35      19              11
# D. Coyne          21             19           33      37              16
#
#               Strength  Vision Volleys Preferred Positions
# Name
# B. Richardson   47      17      12                     GK
# E. El Hadary    73      16      12                     GK
# O. Pérez        66      40      13                     GK
# J. Walker       62      32      11                     GK
# D. Coyne        76      33      11                     GK
#
# [5 rows x 38 columns]

# %%
# Filter on players older than 30.
df[df['Age'] > 30]# the outer df is making it return a list if not we only get a true and false table for all the players in the dataframe
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# M. Neuer            31     Germany       92       58         29      52
# Sergio Ramos        31       Spain       90       75         84      79
# L. Modrić           31     Croatia       89       75         62      93
# G. Chiellini        32       Italy       89       68         92      59
# ...                ...         ...      ...          ...        ...     ...
# P. Jennings         37     England       52       38         40      54
# K. Tokushige        33       Japan       51       25         18      38
# H. Tanaka           34       Japan       49       41         92      58
# Y. Uchimura         32       Japan       48       40         31      33
# B. Richardson       47     England       46       25         44      35
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# M. Neuer           35           48        70       15      ...        55
# Sergio Ramos       60           84        80       66      ...        78
# L. Modrić          94           92        84       78      ...        92
# G. Chiellini       64           57        82       58      ...        59
# ...                   ...          ...       ...      ...  ...           ...
# P. Jennings        50           22        46       18      ...        35
# K. Tokushige       39           12        41       12      ...        31
# H. Tanaka          78           42        47       44      ...        57
# Y. Uchimura        65           57        62       51      ...        60
# B. Richardson      44           22        44       11      ...        12
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# M. Neuer              25             11           61      44
# Sergio Ramos          79             91           77      84
# L. Modrić             73             73           71      82
# G. Chiellini          78             90           78      68
# ...                      ...            ...          ...     ...
# P. Jennings           24             12           38      37
# K. Tokushige          20             12           20      23
# H. Tanaka             48             49           55      76
# Y. Uchimura           40             42           39      29
# B. Richardson         13             13           25      32
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# M. Neuer                   10       83      70      11                     GK
# Sergio Ramos               89       81      63      66                     CB
# L. Modrić                  80       58      90      74                 CDM CM
# G. Chiellini               92       91      50      45                     CB
# ...                           ...      ...     ...     ...                 ...
# P. Jennings                13       43      21      14                     GK
# K. Tokushige               13       62      33       5                     GK
# H. Tanaka                  41       56      42      35                 CDM CM
# Y. Uchimura                42       37      47      38                    CAM
# B. Richardson              12       47      17      12                     GK
#
# [2534 rows x 38 columns]

# %%
#We can also pass multiple conditions in the square brackets by using the | and & operators. Note that each condition should be closed inside round brackets as well.
# Filter on players older than 30 and overall rating greater than 90.
df[(df['Age'] > 30) | (df['Overall'] > 90)] #or operator
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
# ...                ...         ...      ...          ...        ...     ...
# P. Jennings         37     England       52       38         40      54
# K. Tokushige        33       Japan       51       25         18      38
# H. Tanaka           34       Japan       49       41         92      58
# Y. Uchimura         32       Japan       48       40         31      33
# B. Richardson       47     England       46       25         44      35
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# L. Messi           95           95        96       77      ...        88
# Neymar             82           95        92       75      ...        81
# L. Suárez          60           91        83       77      ...        83
# M. Neuer           35           48        70       15      ...        55
# ...                   ...          ...       ...      ...  ...           ...
# P. Jennings        50           22        46       18      ...        35
# K. Tokushige       39           12        41       12      ...        31
# H. Tanaka          78           42        47       44      ...        57
# Y. Uchimura        65           57        62       51      ...        60
# B. Richardson      44           22        44       11      ...        12
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# L. Messi              85             26           87      73
# Neymar                80             33           90      78
# L. Suárez             87             38           77      89
# M. Neuer              25             11           61      44
# ...                      ...            ...          ...     ...
# P. Jennings           24             12           38      37
# K. Tokushige          20             12           20      23
# H. Tanaka             48             49           55      76
# Y. Uchimura           40             42           39      29
# B. Richardson         13             13           25      32
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# L. Messi                   28       59      90      85                     RW
# Neymar                     24       53      80      83                     LW
# L. Suárez                  45       80      84      88                     ST
# M. Neuer                   10       83      70      11                     GK
# ...                           ...      ...     ...     ...                 ...
# P. Jennings                13       43      21      14                     GK
# K. Tokushige               13       62      33       5                     GK
# H. Tanaka                  41       56      42      35                 CDM CM
# Y. Uchimura                42       37      47      38                    CAM
# B. Richardson              12       47      17      12                     GK
#
# [2538 rows x 38 columns]

# %%
df[(df['Age'] > 30) & (df['Overall'] > 90)] #and operator
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# M. Neuer           35           48        70       15      ...        55
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# M. Neuer              25             11           61      44
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# M. Neuer                   10       83      70      11                     GK
#
# [2 rows x 38 columns]

# %%
#We can create new columns from existing ones by simply defining the new name as a string inside square brackets, 
#followed by the function or operation of the other column(s).


# Create column of rating per year of age.
df['Rating Per Year of Age'] = df['Overall'] / df['Age']

# Look at first 5 entries.
df['Rating Per Year of Age'].head()
# Out:
# Name
# Cristiano Ronaldo    2.937500
# L. Messi             3.100000
# Neymar               3.680000
# L. Suárez            3.066667
# M. Neuer             2.967742
# Name: Rating Per Year of Age, dtype: float64

# %%
#
'''Deleting Columns

Columns can be deleted by using the drop() function. The arguments are the column name and the axis which should be equal to 1 if we are deleting columns and 0 if we are deleting rows.

# Drop column just created'''
df = df.drop('Rating Per Year of Age', axis=1)

df.head(15)
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
# R. Lewandowski      28      Poland       91       79         80      78
# De Gea              26       Spain       90       57         38      60
# E. Hazard           26     Belgium       90       93         54      93
# T. Kroos            27     Germany       90       60         60      71
# G. Higuaín          29   Argentina       90       78         50      75
# Sergio Ramos        31       Spain       90       75         84      79
# K. De Bruyne        26     Belgium       89       76         68      80
# T. Courtois         25     Belgium       89       46         23      61
# A. Sánchez          28       Chile       89       88         80      90
# L. Modrić           31     Croatia       89       75         62      93
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# L. Messi           95           95        96       77      ...        88
# Neymar             82           95        92       75      ...        81
# L. Suárez          60           91        83       77      ...        83
# M. Neuer           35           48        70       15      ...        55
# R. Lewandowski     80           89        87       62      ...        83
# De Gea             43           42        64       17      ...        50
# E. Hazard          91           92        87       80      ...        86
# T. Kroos           69           89        85       85      ...        90
# G. Higuaín         69           85        86       68      ...        75
# Sergio Ramos       60           84        80       66      ...        78
# K. De Bruyne       75           87        84       90      ...        90
# T. Courtois        45           23        52       14      ...        32
# A. Sánchez         87           87        86       80      ...        81
# L. Modrić          94           92        84       78      ...        92
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# L. Messi              85             26           87      73
# Neymar                80             33           90      78
# L. Suárez             87             38           77      89
# M. Neuer              25             11           61      44
# R. Lewandowski        88             19           83      79
# De Gea                31             13           58      40
# E. Hazard             79             22           87      79
# T. Kroos              87             69           52      77
# G. Higuaín            88             18           80      72
# Sergio Ramos          79             91           77      84
# K. De Bruyne          85             40           75      87
# T. Courtois           36             16           52      38
# A. Sánchez            84             35           84      85
# L. Modrić             73             73           71      82
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# L. Messi                   28       59      90      85                     RW
# Neymar                     24       53      80      83                     LW
# L. Suárez                  45       80      84      88                     ST
# M. Neuer                   10       83      70      11                     GK
# R. Lewandowski             42       84      78      87                     ST
# De Gea                     21       64      68      13                     GK
# E. Hazard                  27       65      86      79                     LW
# T. Kroos                   82       74      88      82                 CDM CM
# G. Higuaín                 22       85      70      88                     ST
# Sergio Ramos               89       81      63      66                     CB
# K. De Bruyne               51       73      90      82              RM CM CAM
# T. Courtois                18       70      44      12                     GK
# A. Sánchez                 39       72      83      83            RM LW ST LM
# L. Modrić                  80       58      90      74                 CDM CM
#
# [15 rows x 38 columns]

# %%
'''We can also group the data according to desired criteria. Grouping in dataframes can be achieved using the groupby() function.

Depending on your application, you may need to call an aggregation function for the grouped data after the groupby() function call.
Examples of aggregation functions include mean(), sum(), min() and max(). This will result in a column of values from the chosen
aggregation (for numeric columns). Let's look at an example:'''


# Look at the average rating by age (first 5 rows).
df.groupby('Age').mean().head()
# Out:
#        Overall
# Age
# 16   57.846154
# 17   56.089147
# 18   57.287202
# 19   59.430309
# 20   61.559839

# %%
#It is possible to group by more than one column. We simply need to pass the list of columns.

# Look at the average rating by age and nationality (first 15 rows).
df.groupby(['Age', 'Nationality']).mean().head(15)
# Out:
#                    Overall
# Age Nationality
# 16  Argentina    56.000000
#     England      61.500000
#     France       54.000000
#     Germany      57.000000
#     Italy        61.000000
#     Netherlands  62.000000
#     Norway       54.500000
#     Romania      54.000000
#     Spain        58.000000
# 17  Algeria      54.000000
#     Argentina    57.333333
#     Australia    52.000000
#     Austria      54.500000
#     Belgium      58.250000
#     Canada       56.000000

# %%
df.groupby('Age').mean().head()
# Out:
#        Overall
# Age
# 16   57.846154
# 17   56.089147
# 18   57.287202
# 19   59.430309
# 20   61.559839

# %%
# Create function.
def position_type(s):

    """"This function converts the individual positions (abbreviations) and classifies it
    as either a forward, midfielder, back or goalkeeper"""

    if (s[-2] == 'T') | (s[-2] == 'W'):
        return 'Forward'
    elif s[-2] == 'M':
        return 'Midfielder'
    elif s[-2] == 'B':
        return 'Back'
    else:
        return 'GoalKeeper'

# Create position type column.
df['Preferred Positions Type'] = df['Preferred Positions'].apply(position_type)

# Look at first 5 entries.
df['Preferred Positions Type'].head()
# Out:
# Name
# Cristiano Ronaldo       Forward
# L. Messi                Forward
# Neymar                  Forward
# L. Suárez               Forward
# M. Neuer             GoalKeeper
# Name: Preferred Positions Type, dtype: object

# %%
df
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
# ...                ...         ...      ...          ...        ...     ...
# A. Kelsey           17     England       46       24         16      38
# B. Richardson       47     England       46       25         44      35
# J. Young            17    Scotland       46       66         26      60
# J. Lundstram        18     England       46       57         46      58
# L. Sackey           18       Ghana       46       48         52      49
#
#                   Balance Ball control Composure Crossing  ... Shot power  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...     94
# L. Messi           95           95        96       77      ...     85
# Neymar             82           95        92       75      ...     80
# L. Suárez          60           91        83       77      ...     87
# M. Neuer           35           48        70       15      ...     25
# ...                   ...          ...       ...      ...  ...        ...
# A. Kelsey          26           12        23       14      ...     19
# B. Richardson      44           22        44       11      ...     13
# J. Young           77           41        50       28      ...     42
# J. Lundstram       74           43        45       34      ...     43
# L. Sackey          47           32        33       19      ...     21
#
#                   Sliding tackle Sprint speed Stamina Standing tackle  \
# Name
# Cristiano Ronaldo         23           91      92              31
# L. Messi                  26           87      73              28
# Neymar                    33           90      78              24
# L. Suárez                 38           77      89              45
# M. Neuer                  11           61      44              10
# ...                          ...          ...     ...             ...
# A. Kelsey                 10           32      28              11
# B. Richardson             13           25      32              12
# J. Young                  14           51      33              17
# J. Lundstram              47           58      49              48
# L. Sackey                 43           49      55              44
#
#                   Strength  Vision Volleys Preferred Positions  \
# Name
# Cristiano Ronaldo   80      85      88                  ST LW
# L. Messi            59      90      85                     RW
# Neymar              53      80      83                     LW
# L. Suárez           80      84      88                     ST
# M. Neuer            83      70      11                     GK
# ...                    ...     ...     ...                 ...
# A. Kelsey           50      26       6                     GK
# B. Richardson       47      17      12                     GK
# J. Young            32      37      33                     ST
# J. Lundstram        46      51      25                     CM
# L. Sackey           67      22      19                  ST CB
#
#                   Preferred Positions Type
# Name
# Cristiano Ronaldo                  Forward
# L. Messi                           Forward
# Neymar                             Forward
# L. Suárez                          Forward
# M. Neuer                        GoalKeeper
# ...                                    ...
# A. Kelsey                       GoalKeeper
# B. Richardson                   GoalKeeper
# J. Young                           Forward
# J. Lundstram                    Midfielder
# L. Sackey                             Back
#
# [17981 rows x 39 columns]

# %%
df.groupby('Age').mean().head()
# Out:
#        Overall
# Age
# 16   57.846154
# 17   56.089147
# 18   57.287202
# 19   59.430309
# 20   61.559839

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17981 entries, Cristiano Ronaldo to L. Sackey
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       17981 non-null  int64
#  1   Nationality               17981 non-null  object
#  2   Overall                   17981 non-null  int64
#  3   Acceleration              17981 non-null  object
#  4   Aggression                17981 non-null  object
#  5   Agility                   17981 non-null  object
#  6   Balance                   17981 non-null  object
#  7   Ball control              17981 non-null  object
#  8   Composure                 17981 non-null  object
#  9   Crossing                  17981 non-null  object
#  10  Curve                     17981 non-null  object
#  11  Dribbling                 17981 non-null  object
#  12  Finishing                 17981 non-null  object
#  13  Free kick accuracy        17981 non-null  object
#  14  GK diving                 17981 non-null  object
#  15  GK handling               17981 non-null  object
#  16  GK kicking                17981 non-null  object
#  17  GK positioning            17981 non-null  object
#  18  GK reflexes               17981 non-null  object
#  19  Heading accuracy          17981 non-null  object
#  20  Interceptions             17981 non-null  object
#  21  Jumping                   17981 non-null  object
#  22  Long passing              17981 non-null  object
#  23  Long shots                17981 non-null  object
#  24  Marking                   17981 non-null  object
#  25  Penalties                 17981 non-null  object
#  26  Positioning               17981 non-null  object
#  27  Reactions                 17981 non-null  object
#  28  Short passing             17981 non-null  object
#  29  Shot power                17981 non-null  object
#  30  Sliding tackle            17981 non-null  object
#  31  Sprint speed              17981 non-null  object
#  32  Stamina                   17981 non-null  object
#  33  Standing tackle           17981 non-null  object
#  34  Strength                  17981 non-null  object
#  35  Vision                    17981 non-null  object
#  36  Volleys                   17981 non-null  object
#  37  Preferred Positions       17981 non-null  object
#  38  Preferred Positions Type  17981 non-null  object
# dtypes: int64(2), object(37)
# memory usage: 6.0+ MB

# %%
df.dtypes #checking the types of our data and object means string
# Out:
# Age                          int64
# Nationality                 object
# Overall                      int64
# Acceleration                object
# Aggression                  object
# Agility                     object
# Balance                     object
# Ball control                object
# Composure                   object
# Crossing                    object
# Curve                       object
# Dribbling                   object
# Finishing                   object
# Free kick accuracy          object
# GK diving                   object
# GK handling                 object
# GK kicking                  object
# GK positioning              object
# GK reflexes                 object
# Heading accuracy            object
# Interceptions               object
# Jumping                     object
# Long passing                object
# Long shots                  object
# Marking                     object
# Penalties                   object
# Positioning                 object
# Reactions                   object
# Short passing               object
# Shot power                  object
# Sliding tackle              object
# Sprint speed                object
# Stamina                     object
# Standing tackle             object
# Strength                    object
# Vision                      object
# Volleys                     object
# Preferred Positions         object
# Preferred Positions Type    object
# dtype: object

# %%
cols = ['Overall', 'Acceleration', 'Aggression','Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve','Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving','GK handling', 'GK kicking', 'GK positioning', 'GK reflexes','Heading accuracy', 'Interceptions', 'Jumping', 'Long passing','Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions','Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed','Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys']

# %%
# Use applymap() function to transform all selected columns.
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8584/3569958603.py in <module>
#       1 # Use applymap() function to transform all selected columns.
# ----> 2 df[cols] = df[cols].apply(pd.to_numeric, errors='coerce', axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Overall', 'Acceleration', 'Aggression', 'Agility', 'Balance',\n       'Ball control', 'Composure', 'Crossing', 'Curve', 'Dribbling',\n       'Finishing', 'Free kick accuracy', 'GK diving', 'GK handling',\n       'GK kicking', 'GK positioning', 'GK reflexes', 'Heading accuracy',\n       'Interceptions', 'Jumping', 'Long passing', 'Long shots', 'Marking',\n       'Penalties', 'Positioning', 'Reactions', 'Short passing', 'Shot power',\n       'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',\n       'Strength', 'Vision', 'Volleys'],\n      dtype='object')] are in the [columns]"

# %%
#List all columns for players that have 'CB' as at least one of their preferred positions.
df[df['Preferred Positions'].str.contains('CB')]
# Out:
#                Age          Nationality  Overall  Acceleration  Aggression  \
# Name
# Sergio Ramos    31                Spain     90.0          75.0        84.0
# G. Chiellini    32                Italy     89.0          68.0        92.0
# L. Bonucci      30                Italy     88.0          62.0        82.0
# J. Boateng      28              Germany     88.0          72.0        82.0
# D. Godín        31              Uruguay     88.0          62.0        86.0
# ...            ...                  ...      ...           ...         ...
# T. Brownsword   17              England     47.0          55.0        47.0
# A. Kilgour      19              England     47.0          52.0        56.0
# A. Conway       19  Republic of Ireland     47.0          60.0        44.0
# J. Keeble       18              England     46.0          66.0        40.0
# L. Sackey       18                Ghana     46.0          48.0        52.0
#
#                Agility  Balance  Ball control  Composure  Crossing  ...  \
# Name                                                                ...
# Sergio Ramos      79.0     60.0          84.0       80.0      66.0  ...
# G. Chiellini      59.0     64.0          57.0       82.0      58.0  ...
# L. Bonucci        60.0     52.0          75.0       84.0      44.0  ...
# J. Boateng        58.0     53.0          71.0       86.0      69.0  ...
# D. Godín          63.0     58.0          76.0       82.0      55.0  ...
# ...                ...      ...           ...        ...       ...  ...
# T. Brownsword     49.0     59.0          30.0       48.0      25.0  ...
# A. Kilgour        60.0     51.0          42.0       38.0      29.0  ...
# A. Conway         47.0     54.0          28.0       43.0      51.0  ...
# J. Keeble         45.0     48.0          34.0       37.0      28.0  ...
# L. Sackey         49.0     47.0          32.0       33.0      19.0  ...
#
#                Shot power  Sliding tackle  Sprint speed  Stamina  \
# Name
# Sergio Ramos         79.0            91.0          77.0     84.0
# G. Chiellini         78.0            90.0          78.0     68.0
# L. Bonucci           74.0            88.0          72.0     73.0
# J. Boateng           79.0            90.0          78.0     74.0
# D. Godín             67.0            89.0          67.0     67.0
# ...                   ...             ...           ...      ...
# T. Brownsword        32.0            54.0          63.0     59.0
# A. Kilgour           43.0            43.0          55.0     61.0
# A. Conway            44.0            43.0          58.0     52.0
# J. Keeble            30.0            49.0          60.0     52.0
# L. Sackey            21.0            43.0          49.0     55.0
#
#                Standing tackle  Strength  Vision  Volleys  \
# Name
# Sergio Ramos              89.0      81.0    63.0     66.0
# G. Chiellini              92.0      91.0    50.0     45.0
# L. Bonucci                88.0      85.0    74.0     58.0
# J. Boateng                91.0      91.0    76.0     53.0
# D. Godín                  86.0      80.0    52.0     47.0
# ...                        ...       ...     ...      ...
# T. Brownsword             51.0      50.0    32.0     21.0
# A. Kilgour                46.0      68.0    31.0     19.0
# A. Conway                 48.0      48.0    40.0     33.0
# J. Keeble                 52.0      42.0    28.0     24.0
# L. Sackey                 44.0      67.0    22.0     19.0
#
#                Preferred Positions  Preferred Positions Type
# Name
# Sergio Ramos                   CB                       Back
# G. Chiellini                   CB                       Back
# L. Bonucci                     CB                       Back
# J. Boateng                     CB                       Back
# D. Godín                       CB                       Back
# ...                            ...                       ...
# T. Brownsword                  CB                       Back
# A. Kilgour                     CB                       Back
# A. Conway            CB LW LWB LB                       Back
# J. Keeble                      CB                       Back
# L. Sackey                   ST CB                       Back
#
# [3630 rows x 39 columns]

# %%
#List the mean age of players of each nationality in descending order

df.groupby(['Nationality'])['Age'].mean().sort_values(ascending=False)# ascending = false makes it go in a descending order
# Out:
# Nationality
# Oman                 35.0
# Puerto Rico          34.5
# Eritrea              32.0
# Guatemala            31.0
# Turkmenistan         30.0
#                      ...
# Thailand             21.5
# Liberia              21.5
# Swaziland            20.0
# Brunei Darussalam    19.0
# Hong Kong            17.0
# Name: Age, Length: 165, dtype: float64

# %%
#Using the apply and lambda functions, convert the "Age" of all players older than 36 years into floats.

# %%
df.dtypes #checking just hte data types
# Out:
# Age                           int64
# Nationality                  object
# Overall                     float64
# Acceleration                float64
# Aggression                  float64
# Agility                     float64
# Balance                     float64
# Ball control                float64
# Composure                   float64
# Crossing                    float64
# Curve                       float64
# Dribbling                   float64
# Finishing                   float64
# Free kick accuracy          float64
# GK diving                   float64
# GK handling                 float64
# GK kicking                  float64
# GK positioning              float64
# GK reflexes                 float64
# Heading accuracy            float64
# Interceptions               float64
# Jumping                     float64
# Long passing                float64
# Long shots                  float64
# Marking                     float64
# Penalties                   float64
# Positioning                 float64
# Reactions                   float64
# Short passing               float64
# Shot power                  float64
# Sliding tackle              float64
# Sprint speed                float64
# Stamina                     float64
# Standing tackle             float64
# Strength                    float64
# Vision                      float64
# Volleys                     float64
# Preferred Positions          object
# Preferred Positions Type     object
# dtype: object

# %%
df.info()#checking the data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17981 entries, Cristiano Ronaldo to L. Sackey
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       17981 non-null  int64
#  1   Nationality               17981 non-null  object
#  2   Overall                   17981 non-null  float64
#  3   Acceleration              17981 non-null  float64
#  4   Aggression                17981 non-null  float64
#  5   Agility                   17981 non-null  float64
#  6   Balance                   17981 non-null  float64
#  7   Ball control              17981 non-null  float64
#  8   Composure                 17981 non-null  float64
#  9   Crossing                  17981 non-null  float64
#  10  Curve                     17981 non-null  float64
#  11  Dribbling                 17981 non-null  float64
#  12  Finishing                 17981 non-null  float64
#  13  Free kick accuracy        17981 non-null  float64
#  14  GK diving                 17981 non-null  float64
#  15  GK handling               17981 non-null  float64
#  16  GK kicking                17981 non-null  float64
#  17  GK positioning            17981 non-null  float64
#  18  GK reflexes               17981 non-null  float64
#  19  Heading accuracy          17981 non-null  float64
#  20  Interceptions             17981 non-null  float64
#  21  Jumping                   17981 non-null  float64
#  22  Long passing              17981 non-null  float64
#  23  Long shots                17981 non-null  float64
#  24  Marking                   17981 non-null  float64
#  25  Penalties                 17981 non-null  float64
#  26  Positioning               17981 non-null  float64
#  27  Reactions                 17981 non-null  float64
#  28  Short passing             17981 non-null  float64
#  29  Shot power                17981 non-null  float64
#  30  Sliding tackle            17981 non-null  float64
#  31  Sprint speed              17981 non-null  float64
#  32  Stamina                   17981 non-null  float64
#  33  Standing tackle           17981 non-null  float64
#  34  Strength                  17981 non-null  float64
#  35  Vision                    17981 non-null  float64
#  36  Volleys                   17981 non-null  float64
#  37  Preferred Positions       17981 non-null  object
#  38  Preferred Positions Type  17981 non-null  object
# dtypes: float64(35), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
# Import libraries 
import matplotlib.pyplot as plt #used for plotting data 
import numpy as np #used for mathematical operations
import pandas as pd #used to loading CSV data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Explore-AI/Public-Data/master/Data/tips.csv")#pd.read_csv() its a fuction to get our files into our notebook

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
title_day = df.groupby('day').sum() #group and sum data by the number of values for each ‘day’ category
print(title_day)
# Out:
#       total_bill     tip  size
# day
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216
# Thur     1096.33  171.83   152

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
week_day = title_day.total_bill.sort_values().index #sort the indices 
bill = title_day.total_bill.sort_values()

print(bill)
# Out:
# day
# Fri      325.88
# Thur    1096.33
# Sun     1627.16
# Sat     1778.40
# Name: total_bill, dtype: float64

# %%
print(week_day)
# Out:
# Index(['Fri', 'Thur', 'Sun', 'Sat'], dtype='object', name='day')

# %%
# Plot total bill (y-axis) for day of the week (x-axis) 
# We only have to call a single line of code from matplotlib to produce the base graph. 
plt.bar(week_day, bill, color= 'orange')

# Set x and y axis titles
plt.ylabel('Total Bill')
plt.xlabel('\n Days of the Week(Thur-Sun)') # Note: '\n' creates a newline (try removing it and see what happens)  

# Set graph title
plt.title('Total bill of customers for Thur-Sun \n')

# Show graph
plt.show()

# %%
title_time = df.groupby('time').sum() # Group and sum data by the number of values for each ‘time’ category
print(title_time)
# Out:
#         total_bill     tip  size
# time
# Dinner     3660.30  546.07   463
# Lunch      1167.47  185.51   164

# %%
meal_time = title_time.tip.sort_values().index #Sort the indices 
tips = title_time.tip.sort_values()
print(tips)
# Out:
# time
# Lunch     185.51
# Dinner    546.07
# Name: tip, dtype: float64

# %%
print(meal_time)
# Out:
# Index(['Lunch', 'Dinner'], dtype='object', name='time')

# %%
# Plot a pie chart
# The `autopct` argument defines the format applied to the data labels. 
# The `startangle` argument determines which point in the pie to start plotting proportions from. 
# Full plot documentation can be found here: https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.pie.html 
plt.pie(tips, labels = meal_time, autopct='%1.1f%%',  startangle=140)

# Place the chart legend in a position which does not overlap with other components. 
plt.legend(loc="best")
plt.axis('equal')
plt.show()

# %%
total_meals = {'31/01/1990': 1340, '28/02/1990': 1338, '31/03/1990': 1330, '30/04/1990': 1328, '31/05/1990': 1335, '30/06/1990': 1335}

# %%
dates = list(total_meals.keys()) # Extract the dates (the dictionary keys of our data in this case)
x_ax = [date[3:5] for date in dates] # Extract the month from each date string
y_ax = list(total_meals.values()) # Extract the total number of meals consumed on each date as a Python list

# Plot the line graph
plt.plot(x_ax, y_ax, color='indigo')

# Set axis and graph titles
plt.xlabel('Month')
plt.ylabel('Number of Total meals sold')
plt.title('Line Graph Showing the Total Number of Meals Sold Over the First 6 Months of 1990 \n')

plt.show()

# %%
print(dates)
print(y_ax)
print(x_ax)
# Out:
# ['31/01/1990', '28/02/1990', '31/03/1990', '30/04/1990', '31/05/1990', '30/06/1990']
# [1340, 1338, 1330, 1328, 1335, 1335]
# ['01', '02', '03', '04', '05', '06']

# %%
# For this plot, we need to access the underlying Axes object used to create our chart. 
# To display our data correctly, we also set the `figsize` argument to increase the size of the plot. 
fig, ax = plt.subplots(figsize=(10,5))

# Create the scatter plot, with the 'size' variable being coded as the marker colour. 
# We set the `alpha` parameter to make the markers slightly transparent to view overlapping points. 
scatter = ax.scatter(df['total_bill'], df['tip'], c=df['size'], alpha=0.5)#alpha= color intensity 

# We now create our legend based upon the underlying group size and colour assignments.
ax.legend(*scatter.legend_elements(), loc="best", title="Group Size")

# Set graph and axis titles
plt.title('Scatter Plot Showing the Average Amount Tipped vs Group Size \n')
plt.xlabel('Bill Total ($)')
plt.ylabel('Amount Tipped ($)')

plt.show()

# %%
smokers=df.groupby('smoker').sum()

# %%
x_axis= smokers.total_bill.sort_values().index
y_axis= smokers.total_bill.sort_values()

plt.bar(x_axis, y_axis, color= 'gold', alpha= 0.8)

plt.ylabel('Total Bill')
plt.xlabel ('\n Smoker Status')
plt.title('Smokers Total Bill\n')
plt.show()

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

soccer = pd.read_csv("https://raw.githubusercontent.com/Explore-AI/Public-Data/master/Data/fundamentals/football_players.csv",low_memory=False)

# %%
cols = ['Age', 'Overall', 'Acceleration', 'Aggression',
       'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
       'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
       'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
       'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
       'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
       'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
       'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys']

soccer[cols] = soccer[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
soccer.head()
# Out:
#                 Name   Age Nationality  Overall  Acceleration  Aggression  \
# 0  Cristiano Ronaldo  32.0    Portugal     94.0          89.0        63.0
# 1           L. Messi  30.0   Argentina     93.0          92.0        48.0
# 2             Neymar  25.0      Brazil     92.0          94.0        56.0
# 3          L. Suárez  30.0     Uruguay     92.0          88.0        78.0
# 4           M. Neuer  31.0     Germany     92.0          58.0        29.0
#
#    Agility  Balance  Ball control  Composure  ...  Short passing  Shot power  \
# 0     89.0     63.0          93.0       95.0  ...           83.0        94.0
# 1     90.0     95.0          95.0       96.0  ...           88.0        85.0
# 2     96.0     82.0          95.0       92.0  ...           81.0        80.0
# 3     86.0     60.0          91.0       83.0  ...           83.0        87.0
# 4     52.0     35.0          48.0       70.0  ...           55.0        25.0
#
#    Sliding tackle  Sprint speed  Stamina  Standing tackle  Strength  Vision  \
# 0            23.0          91.0     92.0             31.0      80.0    85.0
# 1            26.0          87.0     73.0             28.0      59.0    90.0
# 2            33.0          90.0     78.0             24.0      53.0    80.0
# 3            38.0          77.0     89.0             45.0      80.0    84.0
# 4            11.0          61.0     44.0             10.0      83.0    70.0
#
#    Volleys  Preferred Positions
# 0     88.0               ST LW
# 1     85.0                  RW
# 2     83.0                  LW
# 3     88.0                  ST
# 4     11.0                  GK
#
# [5 rows x 39 columns]

# %%
soccer.describe()
# Out:
#                 Age       Overall  Acceleration   Aggression       Agility  \
# count  17981.000000  17981.000000  17926.000000  17928.00000  17937.000000
# mean      25.144541     66.247984    103.446893     77.59923     98.150248
# std        4.614272      6.987965    986.386054    768.79730    910.809847
# min       16.000000     46.000000     11.000000     11.00000     14.000000
# 25%       21.000000     62.000000     56.000000     43.00000     55.000000
# 50%       25.000000     66.000000     67.000000     59.00000     65.000000
# 75%       28.000000     71.000000     75.000000     69.00000     74.000000
# max       47.000000     94.000000  33270.000000  43130.00000  30164.000000
#
#             Balance  Ball control     Composure      Crossing         Curve  \
# count  17941.000000  17888.000000  17923.000000  17915.000000  17920.000000
# mean      86.616911    121.420338    103.764995     86.550600     62.586496
# std      752.123941   1236.108966   1028.086556    912.376407    623.794730
# min       11.000000      8.000000      5.000000      5.000000      6.000000
# 25%       56.000000     53.000000     51.000000     38.000000     34.000000
# 50%       66.000000     63.000000     60.000000     54.000000     48.000000
# 75%       74.000000     69.000000     67.000000     64.000000     62.000000
# max    31472.000000  43145.000000  27150.000000  27150.000000  43131.000000
#
#        ...     Reactions  Short passing    Shot power  Sliding tackle  \
# count  ...  17914.000000   17876.000000  17929.000000    17918.000000
# mean   ...    121.637937     115.298557     83.046796       89.598672
# std    ...   1161.367097    1157.803920    811.145271     1074.217147
# min    ...     28.000000      10.000000      3.000000        4.000000
# 25%    ...     55.250000      53.000000     46.000000       24.000000
# 50%    ...     62.000000      62.000000     59.000000       51.000000
# 75%    ...     68.000000      68.000000     69.000000       64.000000
# max    ...  27760.000000   28856.000000  29677.000000    43372.000000
#
#        Sprint speed       Stamina  Standing tackle      Strength  \
# count  17906.000000  17915.000000     17901.000000  17913.000000
# mean     119.034849    123.126151       109.390425    116.040138
# std     1185.940156   1261.551333      1286.912547   1148.520031
# min       11.000000     12.000000         4.000000     12.000000
# 25%       57.000000     56.000000        26.000000     58.000000
# 50%       67.000000     66.000000        54.000000     66.000000
# 75%       75.000000     74.000000        66.000000     74.000000
# max    32905.000000  43433.000000     43144.000000  31868.000000
#
#              Vision       Volleys
# count  17904.000000  17950.000000
# mean      91.195878     54.622507
# std      945.840135    523.716920
# min       10.000000      4.000000
# 25%       43.000000     30.000000
# 50%       54.000000     44.000000
# 75%       64.000000     57.000000
# max    28216.000000  43129.000000
#
# [8 rows x 36 columns]

# %%
for column in soccer.describe().columns:
    soccer[column] = soccer[column].apply(lambda x: x if x<=100 else np.nan)

soccer.describe()
# Out:
#                 Age       Overall  Acceleration    Aggression       Agility  \
# count  17981.000000  17981.000000  17897.000000  17913.000000  17910.000000
# mean      25.144541     66.247984     64.576521     55.791492     63.333613
# std        4.614272      6.987965     14.918313     17.476572     14.802800
# min       16.000000     46.000000     11.000000     11.000000     14.000000
# 25%       21.000000     62.000000     56.000000     43.000000     55.000000
# 50%       25.000000     66.000000     67.000000     59.000000     65.000000
# 75%       28.000000     71.000000     75.000000     69.000000     74.000000
# max       47.000000     94.000000     96.000000     96.000000     96.000000
#
#             Balance  Ball control     Composure      Crossing         Curve  \
# count  17924.000000  17840.000000  17887.000000  17885.000000  17908.000000
# mean      63.803894     58.071469     57.877341     49.725301     47.261112
# std       14.100950     16.834554     12.938165     18.474237     18.463394
# min       11.000000      8.000000      5.000000      5.000000      6.000000
# 25%       56.000000     53.000000     51.000000     37.000000     34.000000
# 50%       66.000000     63.000000     60.000000     54.000000     48.000000
# 75%       74.000000     69.000000     67.000000     64.000000     62.000000
# max       96.000000     95.000000     96.000000     91.000000     92.000000
#
#        ...     Reactions  Short passing    Shot power  Sliding tackle  \
# count  ...  17866.000000   17832.000000  17908.000000    17886.000000
# mean   ...     61.898802      58.263964     55.622292       45.496645
# std    ...      9.176709      14.947943     17.408483       21.489926
# min    ...     28.000000      10.000000      3.000000        4.000000
# 25%    ...     55.000000      53.000000     46.000000       23.000000
# 50%    ...     62.000000      62.000000     59.000000       51.000000
# 75%    ...     68.000000      68.000000     69.000000       64.000000
# max    ...     96.000000      92.000000     94.000000       91.000000
#
#        Sprint speed       Stamina  Standing tackle      Strength  \
# count  17867.000000  17873.000000     17857.000000  17877.000000
# mean      64.795713     63.233201        47.352187     65.279130
# std       14.649127     15.942738        21.851023     12.618415
# min       11.000000     12.000000         4.000000     12.000000
# 25%       57.000000     56.000000        26.000000     58.000000
# 50%       67.000000     66.000000        54.000000     66.000000
# 75%       75.000000     74.000000        66.000000     74.000000
# max       96.000000     95.000000        92.000000     98.000000
#
#              Vision       Volleys
# count  17874.000000  17940.000000
# mean      52.967495     43.198495
# std       14.387015     17.734259
# min       10.000000      4.000000
# 25%       43.000000     30.000000
# 50%       54.000000     44.000000
# 75%       64.000000     57.000000
# max       94.000000     91.000000
#
# [8 rows x 36 columns]

# %%
soccer.iloc[-1,0]
# Out:
# 'L. Sackey'

# %%
soccer.iloc[0,0]
# Out:
# 'Cristiano Ronaldo'

# %%
soccer.iloc[1:101,:] # selects rows 1 to 100 from the DataFrame
# Out:
#                Name   Age Nationality  Overall  Acceleration  Aggression  \
# 1          L. Messi  30.0   Argentina     93.0          92.0        48.0
# 2            Neymar  25.0      Brazil     92.0          94.0        56.0
# 3         L. Suárez  30.0     Uruguay     92.0          88.0        78.0
# 4          M. Neuer  31.0     Germany     92.0          58.0        29.0
# 5    R. Lewandowski  28.0      Poland     91.0          79.0        80.0
# ..              ...   ...         ...      ...           ...         ...
# 96          D. Alli  21.0     England     84.0          77.0        84.0
# 97          S. Mané  25.0     Senegal     84.0          94.0        73.0
# 98         Carvajal  25.0       Spain     84.0          76.0        81.0
# 99       J. Draxler  23.0     Germany     84.0          76.0        48.0
# 100       M. Icardi  24.0   Argentina     84.0          75.0        55.0
#
#      Agility  Balance  Ball control  Composure  ...  Short passing  \
# 1       90.0     95.0          95.0       96.0  ...           88.0
# 2       96.0     82.0          95.0       92.0  ...           81.0
# 3       86.0     60.0          91.0       83.0  ...           83.0
# 4       52.0     35.0          48.0       70.0  ...           55.0
# 5       78.0     80.0          89.0       87.0  ...           83.0
# ..       ...      ...           ...        ...  ...            ...
# 96      74.0     62.0          85.0       86.0  ...           83.0
# 97      89.0     85.0          84.0       78.0  ...           77.0
# 98      82.0     79.0          83.0       74.0  ...           81.0
# 99      81.0     75.0          87.0       81.0  ...           84.0
# 100     74.0     76.0          77.0       82.0  ...           73.0
#
#      Shot power  Sliding tackle  Sprint speed  Stamina  Standing tackle  \
# 1          85.0            26.0          87.0     73.0             28.0
# 2          80.0            33.0          90.0     78.0             24.0
# 3          87.0            38.0          77.0     89.0             45.0
# 4          25.0            11.0          61.0     44.0             10.0
# 5          88.0            19.0          83.0     79.0             42.0
# ..          ...             ...           ...      ...              ...
# 96         77.0            57.0          76.0     89.0             63.0
# 97         77.0            38.0          92.0     82.0             35.0
# 98         64.0            86.0          86.0     84.0             85.0
# 99         86.0            26.0          79.0     68.0             35.0
# 100        81.0            21.0          80.0     70.0             21.0
#
#      Strength  Vision  Volleys  Preferred Positions
# 1        59.0    90.0     85.0                  RW
# 2        53.0    80.0     83.0                  LW
# 3        80.0    84.0     88.0                  ST
# 4        83.0    70.0     11.0                  GK
# 5        84.0    78.0     87.0                  ST
# ..        ...     ...      ...                  ...
# 96       71.0    83.0     76.0           LM CF CAM
# 97       72.0    78.0     68.0               LW RW
# 98       75.0    57.0     34.0                  RB
# 99       67.0    84.0     84.0           LM CAM LW
# 100      74.0    64.0     81.0                  ST
#
# [100 rows x 39 columns]

# %%
soccer.iloc[0:11,0]
# Out:
# 0     Cristiano Ronaldo
# 1              L. Messi
# 2                Neymar
# 3             L. Suárez
# 4              M. Neuer
# 5        R. Lewandowski
# 6                De Gea
# 7             E. Hazard
# 8              T. Kroos
# 9            G. Higuaín
# 10         Sergio Ramos
# Name: Name, dtype: object

# %%
soccer.sort_values('Agility').max()
# Out:
# Name                   Óscar Whalley
# Age                             47.0
# Nationality                 Zimbabwe
# Overall                         94.0
# Acceleration                    96.0
# Aggression                      96.0
# Agility                         96.0
# Balance                         96.0
# Ball control                    95.0
# Composure                       96.0
# Crossing                        91.0
# Curve                           92.0
# Dribbling                       97.0
# Finishing                       95.0
# Free kick accuracy              93.0
# GK diving                       91.0
# GK handling                     91.0
# GK kicking                      95.0
# GK positioning                  91.0
# GK reflexes                     90.0
# Heading accuracy                94.0
# Interceptions                   92.0
# Jumping                         95.0
# Long passing                    93.0
# Long shots                      92.0
# Marking                         92.0
# Penalties                       92.0
# Positioning                     95.0
# Reactions                       96.0
# Short passing                   92.0
# Shot power                      94.0
# Sliding tackle                  91.0
# Sprint speed                    96.0
# Stamina                         95.0
# Standing tackle                 92.0
# Strength                        98.0
# Vision                          94.0
# Volleys                         91.0
# Preferred Positions        ST RW RM
# dtype: object

# %%
soccer = soccer.rename(columns = {"Preferred Positions": "Preferred_Positions"})
soccer.head()
# Out:
#                 Name   Age Nationality  Overall  Acceleration  Aggression  \
# 0  Cristiano Ronaldo  32.0    Portugal     94.0          89.0        63.0
# 1           L. Messi  30.0   Argentina     93.0          92.0        48.0
# 2             Neymar  25.0      Brazil     92.0          94.0        56.0
# 3          L. Suárez  30.0     Uruguay     92.0          88.0        78.0
# 4           M. Neuer  31.0     Germany     92.0          58.0        29.0
#
#    Agility  Balance  Ball control  Composure  ...  Short passing  Shot power  \
# 0     89.0     63.0          93.0       95.0  ...           83.0        94.0
# 1     90.0     95.0          95.0       96.0  ...           88.0        85.0
# 2     96.0     82.0          95.0       92.0  ...           81.0        80.0
# 3     86.0     60.0          91.0       83.0  ...           83.0        87.0
# 4     52.0     35.0          48.0       70.0  ...           55.0        25.0
#
#    Sliding tackle  Sprint speed  Stamina  Standing tackle  Strength  Vision  \
# 0            23.0          91.0     92.0             31.0      80.0    85.0
# 1            26.0          87.0     73.0             28.0      59.0    90.0
# 2            33.0          90.0     78.0             24.0      53.0    80.0
# 3            38.0          77.0     89.0             45.0      80.0    84.0
# 4            11.0          61.0     44.0             10.0      83.0    70.0
#
#    Volleys  Preferred_Positions
# 0     88.0               ST LW
# 1     85.0                  RW
# 2     83.0                  LW
# 3     88.0                  ST
# 4     11.0                  GK
#
# [5 rows x 39 columns]

# %%
soccer.select_dtypes(include=['object']).head()
# Out:
#                 Name Nationality Preferred_Positions
# 0  Cristiano Ronaldo    Portugal              ST LW
# 1           L. Messi   Argentina                 RW
# 2             Neymar      Brazil                 LW
# 3          L. Suárez     Uruguay                 ST
# 4           M. Neuer     Germany                 GK

# %%
soccer.select_dtypes(include=['float']).head()
# Out:
#     Age  Overall  Acceleration  Aggression  Agility  Balance  Ball control  \
# 0  32.0     94.0          89.0        63.0     89.0     63.0          93.0
# 1  30.0     93.0          92.0        48.0     90.0     95.0          95.0
# 2  25.0     92.0          94.0        56.0     96.0     82.0          95.0
# 3  30.0     92.0          88.0        78.0     86.0     60.0          91.0
# 4  31.0     92.0          58.0        29.0     52.0     35.0          48.0
#
#    Composure  Crossing  Curve  ...  Reactions  Short passing  Shot power  \
# 0       95.0      85.0   81.0  ...       96.0           83.0        94.0
# 1       96.0      77.0   89.0  ...       95.0           88.0        85.0
# 2       92.0      75.0   81.0  ...       88.0           81.0        80.0
# 3       83.0      77.0   86.0  ...       93.0           83.0        87.0
# 4       70.0      15.0   14.0  ...       85.0           55.0        25.0
#
#    Sliding tackle  Sprint speed  Stamina  Standing tackle  Strength  Vision  \
# 0            23.0          91.0     92.0             31.0      80.0    85.0
# 1            26.0          87.0     73.0             28.0      59.0    90.0
# 2            33.0          90.0     78.0             24.0      53.0    80.0
# 3            38.0          77.0     89.0             45.0      80.0    84.0
# 4            11.0          61.0     44.0             10.0      83.0    70.0
#
#    Volleys
# 0     88.0
# 1     85.0
# 2     83.0
# 3     88.0
# 4     11.0
#
# [5 rows x 36 columns]

# %%
soccer.dtypes
# Out:
# Name                    object
# Age                    float64
# Nationality             object
# Overall                float64
# Acceleration           float64
# Aggression             float64
# Agility                float64
# Balance                float64
# Ball control           float64
# Composure              float64
# Crossing               float64
# Curve                  float64
# Dribbling              float64
# Finishing              float64
# Free kick accuracy     float64
# GK diving              float64
# GK handling            float64
# GK kicking             float64
# GK positioning         float64
# GK reflexes            float64
# Heading accuracy       float64
# Interceptions          float64
# Jumping                float64
# Long passing           float64
# Long shots             float64
# Marking                float64
# Penalties              float64
# Positioning            float64
# Reactions              float64
# Short passing          float64
# Shot power             float64
# Sliding tackle         float64
# Sprint speed           float64
# Stamina                float64
# Standing tackle        float64
# Strength               float64
# Vision                 float64
# Volleys                float64
# Preferred_Positions     object
# dtype: object

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(2,1, figsize=(10,8))

sns.histplot(soccer['Age'], bins=5, element="step", ax=ax[0])
sns.histplot(soccer['Age'], bins=5, element="step", kde=True, ax=ax[1])

ax[0].set_title('Histogram for Ages')
ax[1].set_title('Histogram of Ages with distribution')

plt.tight_layout()
plt.show()

# %%
plt.hist(soccer['Age'], bins=5)
plt.show()

# %%
fig, ax = plt.subplots(2,1, figsize=(10,8))

sns.histplot(soccer['Overall'], bins=5, element="step", ax=ax[0])
sns.histplot(soccer['Overall'], bins=5, element="step", kde=True, ax=ax[1])

ax[0].set_title('Histogram for Overall')
ax[1].set_title('Histogram of Overall with distribution')

plt.tight_layout()
plt.show()

# %%
plt.hist(soccer['Overall'], bins= 5)
# Out:
# (array([1286., 6820., 7834., 1949.,   92.]),
#  array([46. , 55.6, 65.2, 74.8, 84.4, 94. ]),
#  <BarContainer object of 5 artists>)

# %%
sns.jointplot(data= soccer, x= 'Aggression', y='Age', kind= 'hex')

plt.suptitle('Jointplot showing the Relationship between Age and Aggression of Football Players', y=1.1)
plt.show()

# %%
young_players = soccer[(soccer['Age'] > 22) & (soccer['Age'] < 27)] #filter ages

plt.figure(figsize=(8,5))#fuction for the visual size. 8 for height 5 for width

sns.boxplot(data=young_players, x='Age', y='Overall')
plt.show()
